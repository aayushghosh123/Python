# %%
a = """hello world"""

print(a)
# Out:
# hello world

# %%
name = 'Raj'
age = 25

s = f"My name is {name} and age is {age}"

print(s)
# Out:
# My name is Raj and age is 25

# %% [markdown]
# List

# %%
a = [1,'raj',True,[1,2]]

print(a)
print(type(a[0]))
# Out:
# [1, 'raj', True, [1, 2]]
# <class 'int'>

# %%
m = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

print(len(m))
print(len(m[0]))
# Out:
# 3
# 3

# %%
l = []
x = int(input())

for i in range(0,x):
    val = input()
    l.append(val)

print(l)
# Out:
# ['1', '2', '3', '4', '5']

# %%
a = [1,2,3,4,5]
print(len(a))
# Out:
# 5

# %%
a = [1,2,3,4,5,10,6]

print(max(a))
# Out:
# 10

# %%
a = [1,2,3,4,5,10,6]

pos1 = int(input('Enter swap position no.1'))
pos2 = int(input('Enter swap position no.2'))

temp = a[pos1]
a[pos1] = a[pos2]
a[pos2] = temp

print(a)
# Out:
# [1, 4, 3, 2, 5, 10, 6]

# %%
a = [1,2,3,4,5,10,6]

val = int(input('Enter the element you want to find in the list'))

if val in a:
    print('Element exist in the list')
else:
    print('Element does not exists in the list')
# Out:
# Element exist in the list

# %%
a = [1,2,3,4,5,10,6]

print(a)
val = int(input('Enter the value you want to find the index of - '))

print(a.index(val))
# Out:
# [1, 2, 3, 4, 5, 10, 6]
# 4

# %%
a = [1,2,3,4,5,10,6,6]

print(a)
print(set(a))
# Out:
# [1, 2, 3, 4, 5, 10, 6, 6]
# {1, 2, 3, 4, 5, 6, 10}

# %%
a = [1,2,3,4,5,10,6,6]

print(a)

a.reverse()

print(a)
# Out:
# [1, 2, 3, 4, 5, 10, 6, 6]
# [6, 6, 10, 5, 4, 3, 2, 1]

# %%
a = [1,2,3,4,5,10,6,6]

print(sum(a))
print(type(sum(a)))
# Out:
# 37
# <class 'int'>

# %%
val = 0
a = [1,2,3,4,5,10,6,6]

for i in a:
    val = val + i

print(val)
# Out:
# 37

# %%
a = [1,2,3,4,5,10,6,6,[10,6,6]]

print(sum(a))

# to make it work, you have to first transform it into a 1-D list.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 a = [1,2,3,4,5,10,6,6,[10,6,6]]
# ----> 3 print(sum(a))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'list'

# %%
a = [1,2,3,4,5,10,6,6.3]

print(sum(a))
# Out:
# 37.3

# %%
a = [1, 2, 3]
b = [4, 5, 6]

a = a + a+ b

print(a)
# Out:
# [1, 2, 3, 1, 2, 3, 4, 5, 6]

# %%
a = [1,2,3,4,5,10,6]

a.sort()
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 10]

# %%
a = [1,2,3,4,5,10,6]

a.sort(reverse = True)
print(a)
# Out:
# [10, 6, 5, 4, 3, 2, 1]

# %% [markdown]
# Tuple

# %%
T = 'Raj','Karan','Shyam', 1,2,3

print(type(T))

TT = 'Raj','Karan','Shyam', 1,2,3

print(type(TT))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
T1 = ("Geeks", "For", "Geeks")

print(type(T1))

for i in T1:
    print(i)
    print(type(i))
# Out:
# <class 'tuple'>
# Geeks
# <class 'str'>
# For
# <class 'str'>
# Geeks
# <class 'str'>

# %%
T1 = ("Geeks", "For", "Geeks")

print(T1[1])
# Out:
# For

# %%
T1 = (0, 1, 2, 3)
T2 = ('Geeks', 'For', 'Geeks')

print(T1 + T2)
# Out:
# (0, 1, 2, 3, 'Geeks', 'For', 'Geeks')
